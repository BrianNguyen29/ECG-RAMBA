# %% [markdown]
# # ECG-RAMBA Demo Inference
#
# This notebook demonstrates how to load a pre-trained model and run inference on a sample ECG record.

# %%
import sys
import os
sys.path.append("../")

from configs.config import CONFIG
from src.model import ECGRambaV7Advanced

# Load Model
model = ECGRambaV7Advanced(CONFIG)
print("Model loaded successfully")
